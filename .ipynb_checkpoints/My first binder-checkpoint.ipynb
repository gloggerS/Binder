# %% [markdown]
# # Binder: Python, Jupyter, Github
#
# Hier möchte ich die Binder Funktionalität testen (ein Notebook online zur Verfügung stellen, sodass Studenten Teile des Codes ändern können).

# %%
import numpy as np
from scipy import stats
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
x = np.arange(-3, 3, 0.01)
y = stats.norm.pdf(x)

# %%
plt.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="944">
